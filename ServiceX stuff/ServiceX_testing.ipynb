# %%
from config import running_backend, default_container  # noqa
from servicex_test_utils import wait_for_request_done, get_servicex_request_data
import requests
from servicex import ServiceXDataset
from servicex.minio_adaptor import MinioAdaptor
from servicex.servicex_adaptor import ServiceXAdaptor
import servicex
from func_adl import EventDataset
import uproot_methods
from numpy import genfromtxt

print("All modules imported.")
# Out:
# All modules imported.

# %%
# This can take a very long time - 15-30 minutes depending on the quality of your connection.
# If it is taking too long, most likely the problem is is the downloading - so look at the log
# from the rucio downloader to track progress (yes, an obvious feature request).
def test_func_adl_query_simple_jets(running_backend):
    query = "(call ResultTTree (call Select (call SelectMany (call EventDataset (list 'localds:bogus')) (lambda (list e) (call (attr e 'Jets') 'AntiKt4EMTopoJets'))) (lambda (list j) (/ (call (attr j 'pt')) 1000.0))) (list 'JetPt') 'analysis' 'junk.root')"
    dataset = "mc15_13TeV:mc15_13TeV.361106.PowhegPythia8EvtGen_AZNLOCTEQ6L1_Zee.merge.DAOD_STDM3.e3601_s2576_s2132_r6630_r6264_p2363_tid05630052_00"
    r = servicex.get_data(query , dataset, running_backend)
    print(len(r.index))
    return r

# %%
array = test_func_adl_query_simple_jets("http://localhost:5000/servicex")
# Out:
# 11355980

# %%
print(len(array.index))
# Out:
# 11355980

# %%
def test_func_adl_query_electrons_and_muons (running_backend):
    query = "(call ResultTTree (call Select (call Select (call EventDataset (list 'localds:bogus')) (lambda (list e) (list (call (attr e 'Electrons') 'Electrons') (call (attr e 'Muons') 'Muons')))) (lambda (list e) (list (call (attr (subscript e 0) 'Select') (lambda (list ele) (call (attr ele 'e')))) (call (attr (subscript e 0) 'Select') (lambda (list ele) (call (attr ele 'pt')))) (call (attr (subscript e 0) 'Select') (lambda (list ele) (call (attr ele 'phi')))) (call (attr (subscript e 0) 'Select') (lambda (list ele) (call (attr ele 'eta')))) (call (attr (subscript e 1) 'Select') (lambda (list mu) (call (attr mu 'e')))) (call (attr (subscript e 1) 'Select') (lambda (list mu) (call (attr mu 'pt')))) (call (attr (subscript e 1) 'Select') (lambda (list mu) (call (attr mu 'phi')))) (call (attr (subscript e 1) 'Select') (lambda (list mu) (call (attr mu 'eta'))))))) (list 'e_E' 'e_pt' 'e_phi' 'e_eta' 'mu_E' 'mu_pt' 'mu_phi' 'mu_eta') 'forkme' 'dude.root')"
    dataset = "mc15_13TeV:mc15_13TeV.361106.PowhegPythia8EvtGen_AZNLOCTEQ6L1_Zee.merge.DAOD_STDM3.e3601_s2576_s2132_r6630_r6264_p2363_tid05630052_00",
    r = servicex.get_data(query, dataset, data_type = "awkward", servicex_endpoint = running_backend)
    return r

# %%
emu = test_func_adl_query_electrons_and_muons("http://localhost:5000/servicex")

# %%
print(emu)
# Out:
# {b'e_E': <JaggedArray [[11678.290453057432] [124352.58759560794 5018.021807808239 28260.79313076634 4866.388771162408] [] ... [167994.90017338746 25607.67724485566 25950.88956615245 ... 16041.8821671694 6253.206926476292 16910.816994632994] [45230.94004367999 41885.42415619056 8183.519427098758] [101387.70455256793 127098.75170143174 3860.0051272222413 18531.43010673125]] at 0x01709519bc08>, b'e_pt': <JaggedArray [[5794.58154296875] [36922.66796875 4514.7587890625 4671.44482421875 3811.003662109375] [] ... [36469.15625 25503.25 13456.806640625 ... 4272.71728515625 4177.89990234375 3152.95556640625] [43632.55859375 39205.66796875 3786.251953125] [39072.98828125 43704.296875 3854.654541015625 3911.02734375]] at 0x01709519b848>, b'e_phi': <JaggedArray [[-0.7931161522865295] [2.266842842102051 0.4230227470397949 -0.7722882032394409 3.0246007442474365] [] ... [-2.1718931198120117 -2.48415470123291 2.543349504470825 ... -0.42512843012809753 0.5396857857704163 0.6070034503936768] [-2.516613483428955 0.4820100665092468 2.3127856254577637] [0.4636102020740509 -2.5574259757995605 1.4891444444656372 2.692172050476074]] at 0x01709519b148>, b'e_eta': <JaggedArray [[-1.3257930278778076] [-1.8846356868743896 0.4678869843482971 -2.4862523078918457 -0.7280337810516357] [] ... [-2.208618640899658 0.09046405553817749 -1.274631381034851 ... -1.9978735446929932 -0.9594971537590027 -2.3639543056488037] [-0.2698565125465393 0.3676587641239166 1.40548574924469] [-1.6072806119918823 -1.7297009229660034 0.05268310382962227 -2.2374892234802246]] at 0x01709519b888>, b'mu_E': <JaggedArray [[12508.887514928687] [68003.72402027207 132394.34870029808] [] ... [11975.218919701007] [] [7296.177771002047]] at 0x01709519b748>, b'mu_pt': <JaggedArray [[6687.41845703125] [48828.21875 22644.7578125] [] ... [3822.9697265625] [] [2353.66845703125]] at 0x01709519bac8>, b'mu_phi': <JaggedArray [[2.9998934268951416] [1.9398573637008667 -1.791720986366272] [] ... [-1.4869402647018433] [] [1.2357184886932373]] at 0x01709519b448>, b'mu_eta': <JaggedArray [[-1.2387009859085083] [-0.8595364689826965 -2.451608180999756] [] ... [1.8084065914154053] [] [1.797317624092102]] at 0x0170948b04c8>}

# %%
def test_func_adl_query_simple_jets_large_sample(running_backend):
    'Do not run this unless you have a large well connected system at your beck and call!!'

    query = "(call ResultTTree (call Select (call SelectMany (call EventDataset (list 'localds:bogus')) (lambda (list e) (call (attr e 'Jets') 'AntiKt4EMTopoJets'))) (lambda (list j) (/ (call (attr j 'pt')) 1000.0))) (list 'JetPt') 'analysis' 'junk.root')"
    dataset = "data17_13TeV:data17_13TeV.periodK.physics_Main.PhysCont.DAOD_STDM7.grp22_v01_p3713"
    r = servicex.get_data(query, dataset, servicex_endpoint = running_backend)
    print(r)

print("Large jet tests defined.")
# Out:
# Large jet tests defined.

# %%
test_func_adl_query_simple_jets_large_sample("http://localhost:5000/servicex")

# %%
def test_retrieve_simple_jet_pts():
    query = "(call ResultTTree (call Select (call SelectMany (call EventDataset (list 'localds:bogus')) (lambda (list e) (call (attr e 'Jets') 'AntiKt4EMTopoJets'))) (lambda (list j) (/ (call (attr j 'pt')) 1000.0))) (list 'JetPt') 'analysis' 'junk.root')"
    dataset = "mc15_13TeV:mc15_13TeV.361106.PowhegPythia8EvtGen_AZNLOCTEQ6L1_Zee.merge.DAOD_STDM3.e3601_s2576_s2132_r6630_r6264_p2363_tid05630052_00"
    ds = ServiceXDataset(dataset)
    r = ds.get_data_pandas_df(query)
    return r

# %%
uproot = test_retrieve_simple_jet_pts()
# Out:
# ---------------------------------------------------------------------------
# ServiceXException                         Traceback (most recent call last)
# <ipython-input-11-137b76ded0cb> in <module>
# ----> 1 uproot = test_retrieve_simple_jet_pts()
#
# <ipython-input-10-1fe9addd4549> in test_retrieve_simple_jet_pts()
#       3     dataset = "mc15_13TeV:mc15_13TeV.361106.PowhegPythia8EvtGen_AZNLOCTEQ6L1_Zee.merge.DAOD_STDM3.e3601_s2576_s2132_r6630_r6264_p2363_tid05630052_00"
#       4     ds = ServiceXDataset(dataset)
# ----> 5     r = ds.get_data_pandas_df(query)
#       6     return r
#
# f:\program files (x86)\python 3.7\lib\site-packages\make_it_sync\func_wrapper.py in wrapped_call(*args, **kwargs)
#      55                 raise NotImplementedError(
#      56                     f'Function {func_name} is not implemented by {args[0].__name__}')
# ---> 57             return _sync_version_of_function(v, *(args[1:]), **kwargs)
#      58         del wrapped_call.__isabstractmethod__
#      59         return wrapped_call
#
# f:\program files (x86)\python 3.7\lib\site-packages\make_it_sync\func_wrapper.py in _sync_version_of_function(fn, *args, **kwargs)
#      24         future = exector.submit(get_data_wrapper, *args, **kwargs)
#      25
# ---> 26         return future.result()
#      27
#      28
#
# f:\program files (x86)\python 3.7\lib\concurrent\futures\_base.py in result(self, timeout)
#     433                 raise CancelledError()
#     434             elif self._state == FINISHED:
# --> 435                 return self.__get_result()
#     436             else:
#     437                 raise TimeoutError()
#
# f:\program files (x86)\python 3.7\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# f:\program files (x86)\python 3.7\lib\concurrent\futures\thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# f:\program files (x86)\python 3.7\lib\site-packages\make_it_sync\func_wrapper.py in get_data_wrapper(*args, **kwargs)
#      19             asyncio.set_event_loop(loop)
#      20             assert not loop.is_running()
# ---> 21             return loop.run_until_complete(fn(*args, **kwargs))
#      22
#      23         exector = ThreadPoolExecutor(max_workers=1)
#
# f:\program files (x86)\python 3.7\lib\asyncio\base_events.py in run_until_complete(self, future)
#     585             raise RuntimeError('Event loop stopped before Future completed.')
#     586
# --> 587         return future.result()
#     588
#     589     def stop(self):
#
# f:\program files (x86)\python 3.7\lib\site-packages\servicex\servicex_utils.py in cached_version_of_fn(*args, **kwargs)
#      47         try:
#      48             logger.debug(f'{h} - processing request')
# ---> 49             result = await fn(*args, **kwargs)
#      50             sx._cache.set_inmem(h, result)
#      51         finally:
#
# f:\program files (x86)\python 3.7\lib\site-packages\servicex\servicex.py in get_data_pandas_df_async(self, selection_query)
#      98     async def get_data_pandas_df_async(self, selection_query: str):
#      99         import pandas as pd
# --> 100         return pd.concat(await self._data_return(selection_query, _convert_root_to_pandas))
#     101
#     102     @functools.wraps(ServiceXABC.get_data_awkward_async, updated=())
#
# f:\program files (x86)\python 3.7\lib\site-packages\backoff\_async.py in retry(*args, **kwargs)
#     131
#     132             try:
# --> 133                 ret = await target(*args, **kwargs)
#     134             except exception as e:
#     135                 giveup_result = await giveup(e)
#
# f:\program files (x86)\python 3.7\lib\site-packages\servicex\servicex.py in _data_return(self, selection_query, converter, data_format)
#     169         # Finally, we need them in the proper order so we append them
#     170         # all together
# --> 171         all_data = {f[0]: await f[1] async for f in as_data}  # type: ignore
#     172         ordered_data = [all_data[k] for k in sorted(all_data)]
#     173
#
# f:\program files (x86)\python 3.7\lib\site-packages\servicex\servicex.py in <dictcomp>(.0)
#     169         # Finally, we need them in the proper order so we append them
#     170         # all together
# --> 171         all_data = {f[0]: await f[1] async for f in as_data}  # type: ignore
#     172         ordered_data = [all_data[k] for k in sorted(all_data)]
#     173
#
# f:\program files (x86)\python 3.7\lib\site-packages\servicex\servicex.py in <genexpr>(.0)
#     164
#     165         # Convert them to the proper format
# --> 166         as_data = ((f[0], asyncio.ensure_future(converter(await f[1])))
#     167                    async for f in as_files)  # type: ignore
#     168
#
# f:\program files (x86)\python 3.7\lib\site-packages\servicex\servicex.py in <genexpr>(.0)
#     160         # Get all the files
#     161         as_files = \
# --> 162             (f async for f in
#     163              self._get_files(selection_query, data_format, notifier))
#     164
#
# f:\program files (x86)\python 3.7\lib\site-packages\servicex\servicex.py in _get_files(self, selection_query, data_type, notifier)
#     206
#     207             # Get a request id - which might be cached, but if not, submit it.
# --> 208             request_id = await self._get_request_id(client, query)
#     209
#     210             # Look up the cache, and then fetch an iterator going thorugh the results
#
# f:\program files (x86)\python 3.7\lib\site-packages\servicex\servicex.py in _get_request_id(self, client, query)
#     236         request_id = self._cache.lookup_query(query)
#     237         if request_id is None:
# --> 238             request_id = await self._servicex_adaptor.submit_query(client, query)
#     239             self._cache.set_query(query, request_id)
#     240         return request_id
#
# f:\program files (x86)\python 3.7\lib\site-packages\servicex\servicex_adaptor.py in submit_query(self, client, json_query)
#      82                 # This was an error at ServiceX, bubble it up so code above us can
#      83                 # handle as needed.
# ---> 84                 raise ServiceXException('ServiceX rejected the transformation request: '
#      85                                         f'({status}){r}')
#      86             req_id = r["request_id"]
#
# ServiceXException: (ServiceXException(...), "ServiceX rejected the transformation request: (400){'message': 'Failed to submit transform request: Failed to generate translation code: Unknown id: ResultTTree'}")
